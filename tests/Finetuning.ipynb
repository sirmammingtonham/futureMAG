# %%
import gpt_2_simple as gpt2

# %%
model_name = "345M"
gpt2.download_gpt2(model_name=model_name)
# Out:
# Fetching checkpoint: 1.05Mit [00:00, 1.05Git/s]
# Fetching encoder.json: 1.05Mit [00:00, 5.23Mit/s]
# Fetching hparams.json: 1.05Mit [00:00, 1.05Git/s]
# Fetching model.ckpt.data-00000-of-00001: 1.42Git [21:27, 1.03Mit/s]
# Fetching model.ckpt.index: 1.05Mit [00:00, 526Mit/s]
# Fetching model.ckpt.meta: 1.05Mit [00:00, 5.26Mit/s]
# Fetching vocab.bpe: 1.05Mit [00:00, 7.20Mit/s]

# %%
sess = gpt2.start_tf_sess()

# %%
gpt2.finetune(sess,
              'dataset/montag.txt',
              model_name=model_name,
              steps=1000)
# Out:
# WARNING:tensorflow:From C:\Users\ethan\Anaconda3\envs\futuremag\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From C:\Users\ethan\Anaconda3\envs\futuremag\lib\site-packages\gpt_2_simple\src\sample.py:71: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# WARNING:tensorflow:From C:\Users\ethan\Anaconda3\envs\futuremag\lib\site-packages\gpt_2_simple\src\sample.py:77: multinomial (from tensorflow.python.ops.random_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.random.categorical instead.
# WARNING:tensorflow:From C:\Users\ethan\Anaconda3\envs\futuremag\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# WARNING:tensorflow:From C:\Users\ethan\Anaconda3\envs\futuremag\lib\site-packages\tensorflow\python\ops\math_grad.py:102: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# Loading checkpoint models\345M\model.ckpt
# WARNING:tensorflow:From C:\Users\ethan\Anaconda3\envs\futuremag\lib\site-packages\tensorflow\python\training\saver.py:1266: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# INFO:tensorflow:Restoring parameters from models\345M\model.ckpt
# Loading dataset...
# 100%|████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:01<00:00,  1.45s/it]
# dataset has 213367 tokens
# Training...
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# ~\Anaconda3\envs\futuremag\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1333     try:
# -> 1334       return fn(*args)
#    1335     except errors.OpError as e:
#
# ~\Anaconda3\envs\futuremag\lib\site-packages\tensorflow\python\client\session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1318       return self._call_tf_sessionrun(
# -> 1319           options, feed_dict, fetch_list, target_list, run_metadata)
#    1320
#
# ~\Anaconda3\envs\futuremag\lib\site-packages\tensorflow\python\client\session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1406         self._session, options, feed_dict, fetch_list, target_list,
# -> 1407         run_metadata)
#    1408
#
# ResourceExhaustedError: OOM when allocating tensor with shape[1,16,1024,1024] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[{{node gradients/model/h21/attn/Max_1_grad/Cast}}]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info.
#
#
# During handling of the above exception, another exception occurred:
#
# ResourceExhaustedError                    Traceback (most recent call last)
# <ipython-input-4-4e4e5eba29e2> in <module>
#       2               'dataset/montag.txt',
#       3               model_name=model_name,
# ----> 4               steps=1000)
#
# ~\Anaconda3\envs\futuremag\lib\site-packages\gpt_2_simple\gpt_2.py in finetune(sess, dataset, steps, model_name, combine, batch_size, learning_rate, accumulate_gradients, restore_from, run_name, sample_every, sample_length, sample_num, save_every, print_every, max_checkpoints, use_memory_saving_gradients, only_train_transformer_layers, overwrite)
#     302                 (_, v_loss, v_summary) = sess.run(
#     303                     (opt_apply, loss, summary_loss),
# --> 304                     feed_dict={context: sample_batch()})
#     305
#     306             summary_log.add_summary(v_summary, counter)
#
# ~\Anaconda3\envs\futuremag\lib\site-packages\tensorflow\python\client\session.py in run(self, fetches, feed_dict, options, run_metadata)
#     927     try:
#     928       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 929                          run_metadata_ptr)
#     930       if run_metadata:
#     931         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~\Anaconda3\envs\futuremag\lib\site-packages\tensorflow\python\client\session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1150     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1151       results = self._do_run(handle, final_targets, final_fetches,
# -> 1152                              feed_dict_tensor, options, run_metadata)
#    1153     else:
#    1154       results = []
#
# ~\Anaconda3\envs\futuremag\lib\site-packages\tensorflow\python\client\session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1326     if handle is None:
#    1327       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1328                            run_metadata)
#    1329     else:
#    1330       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# ~\Anaconda3\envs\futuremag\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1346           pass
#    1347       message = error_interpolation.interpolate(message, self._graph)
# -> 1348       raise type(e)(node_def, op, message)
#    1349
#    1350   def _extend_graph(self):
#
# ResourceExhaustedError: OOM when allocating tensor with shape[1,16,1024,1024] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[node gradients/model/h21/attn/Max_1_grad/Cast (defined at C:\Users\ethan\Anaconda3\envs\futuremag\lib\site-packages\gpt_2_simple\src\memory_saving_gradients.py:216) ]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info.
#
#
# Caused by op 'gradients/model/h21/attn/Max_1_grad/Cast', defined at:
#   File "C:\Users\ethan\Anaconda3\envs\futuremag\lib\runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "C:\Users\ethan\Anaconda3\envs\futuremag\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\ethan\Anaconda3\envs\futuremag\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "C:\Users\ethan\Anaconda3\envs\futuremag\lib\site-packages\traitlets\config\application.py", line 658, in launch_instance
#     app.start()
#   File "C:\Users\ethan\Anaconda3\envs\futuremag\lib\site-packages\ipykernel\kernelapp.py", line 505, in start
#     self.io_loop.start()
#   File "C:\Users\ethan\Anaconda3\envs\futuremag\lib\site-packages\tornado\platform\asyncio.py", line 148, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\ethan\Anaconda3\envs\futuremag\lib\asyncio\base_events.py", line 422, in run_forever
#     self._run_once()
#   File "C:\Users\ethan\Anaconda3\envs\futuremag\lib\asyncio\base_events.py", line 1432, in _run_once
#     handle._run()
#   File "C:\Users\ethan\Anaconda3\envs\futuremag\lib\asyncio\events.py", line 145, in _run
#     self._callback(*self._args)
#   File "C:\Users\ethan\Anaconda3\envs\futuremag\lib\site-packages\tornado\ioloop.py", line 690, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "C:\Users\ethan\Anaconda3\envs\futuremag\lib\site-packages\tornado\ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "C:\Users\ethan\Anaconda3\envs\futuremag\lib\site-packages\tornado\gen.py", line 781, in inner
#     self.run()
#   File "C:\Users\ethan\Anaconda3\envs\futuremag\lib\site-packages\tornado\gen.py", line 742, in run
#     yielded = self.gen.send(value)
#   File "C:\Users\ethan\Anaconda3\envs\futuremag\lib\site-packages\ipykernel\kernelbase.py", line 365, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "C:\Users\ethan\Anaconda3\envs\futuremag\lib\site-packages\tornado\gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "C:\Users\ethan\Anaconda3\envs\futuremag\lib\site-packages\ipykernel\kernelbase.py", line 272, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "C:\Users\ethan\Anaconda3\envs\futuremag\lib\site-packages\tornado\gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "C:\Users\ethan\Anaconda3\envs\futuremag\lib\site-packages\ipykernel\kernelbase.py", line 542, in execute_request
#     user_expressions, allow_stdin,
#   File "C:\Users\ethan\Anaconda3\envs\futuremag\lib\site-packages\tornado\gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "C:\Users\ethan\Anaconda3\envs\futuremag\lib\site-packages\ipykernel\ipkernel.py", line 294, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "C:\Users\ethan\Anaconda3\envs\futuremag\lib\site-packages\ipykernel\zmqshell.py", line 536, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "C:\Users\ethan\Anaconda3\envs\futuremag\lib\site-packages\IPython\core\interactiveshell.py", line 2854, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "C:\Users\ethan\Anaconda3\envs\futuremag\lib\site-packages\IPython\core\interactiveshell.py", line 2880, in _run_cell
#     return runner(coro)
#   File "C:\Users\ethan\Anaconda3\envs\futuremag\lib\site-packages\IPython\core\async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\ethan\Anaconda3\envs\futuremag\lib\site-packages\IPython\core\interactiveshell.py", line 3057, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "C:\Users\ethan\Anaconda3\envs\futuremag\lib\site-packages\IPython\core\interactiveshell.py", line 3248, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "C:\Users\ethan\Anaconda3\envs\futuremag\lib\site-packages\IPython\core\interactiveshell.py", line 3325, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-4-4e4e5eba29e2>", line 4, in <module>
#     steps=1000)
#   File "C:\Users\ethan\Anaconda3\envs\futuremag\lib\site-packages\gpt_2_simple\gpt_2.py", line 193, in finetune
#     opt_grads = memory_saving_gradients.gradients(loss, train_vars)
#   File "C:\Users\ethan\Anaconda3\envs\futuremag\lib\site-packages\gpt_2_simple\src\memory_saving_gradients.py", line 216, in gradients
#     dv = tf_gradients(ys=copied_ys, xs=boundary+xs, grad_ys=grad_ys, **kwargs)
#   File "C:\Users\ethan\Anaconda3\envs\futuremag\lib\site-packages\tensorflow\python\ops\gradients_impl.py", line 664, in gradients
#     unconnected_gradients)
#   File "C:\Users\ethan\Anaconda3\envs\futuremag\lib\site-packages\tensorflow\python\ops\gradients_impl.py", line 965, in _GradientsHelper
#     lambda: grad_fn(op, *out_grads))
#   File "C:\Users\ethan\Anaconda3\envs\futuremag\lib\site-packages\tensorflow\python\ops\gradients_impl.py", line 420, in _MaybeCompile
#     return grad_fn()  # Exit early
#   File "C:\Users\ethan\Anaconda3\envs\futuremag\lib\site-packages\tensorflow\python\ops\gradients_impl.py", line 965, in <lambda>
#     lambda: grad_fn(op, *out_grads))
#   File "C:\Users\ethan\Anaconda3\envs\futuremag\lib\site-packages\tensorflow\python\ops\math_grad.py", line 108, in _MaxGrad
#     return _MinOrMaxGrad(op, grad)
#   File "C:\Users\ethan\Anaconda3\envs\futuremag\lib\site-packages\tensorflow\python\ops\math_grad.py", line 98, in _MinOrMaxGrad
#     indicators = math_ops.cast(math_ops.equal(y, op.inputs[0]), grad.dtype)
#   File "C:\Users\ethan\Anaconda3\envs\futuremag\lib\site-packages\tensorflow\python\util\dispatch.py", line 180, in wrapper
#     return target(*args, **kwargs)
#   File "C:\Users\ethan\Anaconda3\envs\futuremag\lib\site-packages\tensorflow\python\ops\math_ops.py", line 616, in cast
#     x = gen_math_ops.cast(x, base_type, name=name)
#   File "C:\Users\ethan\Anaconda3\envs\futuremag\lib\site-packages\tensorflow\python\ops\gen_math_ops.py", line 1897, in cast
#     "Cast", x=x, DstT=DstT, Truncate=Truncate, name=name)
#   File "C:\Users\ethan\Anaconda3\envs\futuremag\lib\site-packages\tensorflow\python\framework\op_def_library.py", line 788, in _apply_op_helper
#     op_def=op_def)
#   File "C:\Users\ethan\Anaconda3\envs\futuremag\lib\site-packages\tensorflow\python\util\deprecation.py", line 507, in new_func
#     return func(*args, **kwargs)
#   File "C:\Users\ethan\Anaconda3\envs\futuremag\lib\site-packages\tensorflow\python\framework\ops.py", line 3300, in create_op
#     op_def=op_def)
#   File "C:\Users\ethan\Anaconda3\envs\futuremag\lib\site-packages\tensorflow\python\framework\ops.py", line 1801, in __init__
#     self._traceback = tf_stack.extract_stack()
#
# ...which was originally created as op 'model/h21/attn/Max_1', defined at:
#   File "C:\Users\ethan\Anaconda3\envs\futuremag\lib\runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
# [elided 27 identical lines from previous traceback]
#   File "C:\Users\ethan\Anaconda3\envs\futuremag\lib\site-packages\gpt_2_simple\gpt_2.py", line 193, in finetune
#     opt_grads = memory_saving_gradients.gradients(loss, train_vars)
#   File "C:\Users\ethan\Anaconda3\envs\futuremag\lib\site-packages\gpt_2_simple\src\memory_saving_gradients.py", line 204, in gradients
#     copied_sgv, info = ge.copy_with_input_replacements(ge.sgv(ops_to_copy), {})
#   File "C:\Users\ethan\Anaconda3\envs\futuremag\lib\site-packages\tensorflow\contrib\graph_editor\transform.py", line 673, in copy_with_input_replacements
#     sgv, dst_graph, dst_scope, src_scope, reuse_dst_scope=reuse_dst_scope)
#   File "C:\Users\ethan\Anaconda3\envs\futuremag\lib\site-packages\tensorflow\contrib\graph_editor\transform.py", line 453, in __call__
#     self._copy_ops(info)
#   File "C:\Users\ethan\Anaconda3\envs\futuremag\lib\site-packages\tensorflow\contrib\graph_editor\transform.py", line 467, in _copy_ops
#     op_, op_outputs_ = self.transform_op_handler(info, op, new_inputs)
#   File "C:\Users\ethan\Anaconda3\envs\futuremag\lib\site-packages\tensorflow\contrib\graph_editor\transform.py", line 177, in copy_op_handler
#     [], input_types_, None, op_def_)
#   File "C:\Users\ethan\Anaconda3\envs\futuremag\lib\site-packages\tensorflow\python\framework\ops.py", line 1801, in __init__
#     self._traceback = tf_stack.extract_stack()
#
# ResourceExhaustedError (see above for traceback): OOM when allocating tensor with shape[1,16,1024,1024] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[node gradients/model/h21/attn/Max_1_grad/Cast (defined at C:\Users\ethan\Anaconda3\envs\futuremag\lib\site-packages\gpt_2_simple\src\memory_saving_gradients.py:216) ]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info.
